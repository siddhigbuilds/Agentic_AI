# %%
print("heyy")

# %% [markdown]
# print("This is from branch Dev1")

# %%
print("this is from dev1")

# %%
print("siddhii")
# Out:
# Running cells with '.venv (Python 3.14.6)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Viki/Anticreate/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
